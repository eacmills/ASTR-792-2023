# %% [markdown]
# # Lecture notes for 11 17 2020

# %% [markdown]
# # Today's Lecture Plan:
#
#
# ## Astrochemistry!
#
#
# ### $\star$ Overview
# ### $\star$ Types of Reactions
# ### $\star$ Line Identification
#
#
# ## Challenge:
#
# Spectral line detectives! Identify molecular lines using Splatalogue.

# %% [markdown]
# # Astrochemistry 101
#
# Chemical reactions in space:
#
# * Are more difficult than reactions on earth (due to low temperatures and extreme low densities). However, they can occur over extremely long timescales (many thousands of years), which does allow complex gas chemistry to arise despite these challenges. Additionally, the low densities also means that some species that don’t last on earth b/c they are so highly reactive (e.g., radicals) can be present in some quantity in the ISM.
# * Do not have high (or any) activation energy/ activation barrier. This is because most rate coefficients (k) have some exponential term exp(-E/kT): remember what happens to such a term if E >> kT!
# * Favor reactions with large (Coulomb-aided) cross sections (e.g., Ion-molecule and dissociative recombination)  because these tend to be faster
#
# Astrochemistry reactions are generally divided into two broad categories: gas-phase and grain-surface reactions.
#
# ### Gas Phase
#
# In the gas phase, chemical reactions proceed via collisions, with a typical collisional rate coefficient on the order of k=$10^{-10}$ cm$^3$ s$^{-1}$.
#
# For a  cold ($T_{kin} =10$ K) and dense ($n= 10^4$  cm$^{-3}$) molecular cloud, we  can then calculate:
#
# * Collision rate per particle of  $k n = 10^{-6}$ s$^{-1}$
# * Timescale =1/Collision rate = $10^6$ s  or 2 weeks
# * Mean free path = Timescale * mean velocity = $10^5$ km
#
# (Note that in order to determine the mean free path we made an assumption that the velocity of the gas was equal to the thermal velocity at 10 K)
#
# Though this seems limiting, it turns out that you can still make a lot of (rather complex!) molecules in ISM gas. HOWEVER, saturated organic species require high temperatures and/or 3-body reactions, and so are not easily formed in the gas phase (the same goes for H$_2$, as we discussed in the **October 29** lecture. )
#
# ### Grain Surfaces
#
# Dust grain surfaces then play a key role in moderating ISM chemistry: as a meeting place to get atoms and molecules together, as a third body to stabilize highly exothermic reactions (and sometimes a shield against UV light, if reactions take place within and under ice layers).
#
# We discussed how to generally form molecules on dust grains in the **October 29** lecture. Once molecules form on grain surfaces:
#
# * If the dust grain is cold enough, the molecules will stick around, and will tend to form ices on the grain surface (Some common ice constituents are H$_2$O, CH$_3$OH, CO$_2$, CH$_4$, NH$_3$)
# * If it is VERY cold, then molecules already in the gas phase will also adhere to the dust grains (this causes depletion of gas-phase species like CO)
# * Molecules can be driven (back) off of dust grains generally through two main processes: shocks and heating (and combinations of the two). Shock sputtering can even erode and destroy the dust grains themselves, releasing components like Si (molecules like SiO are commonly seen to be tracers of shocks).
#
#
#
# ### Important environments for astrochemistry
#
#
# * **Diffuse Clouds** $n<10^2$ cm$^{-3}$, $T = 20-100 $ K: Despite low densities and correspondingly long collisional time scales, a surprising wealth of molecules is observed in these environments. The presence of simple diatomic molecules in the mostly atomic gas is at least in part due to the role played by UV radiation in ionizing atoms and molecules (which then promotes efficient ion-molecule reactions), though UV radiation will also play an important role in destroying molecules. Such rapid photodissociation means that the chemistry observed in these environments is often very close to an equilibrium between formation and destruction. The formation of more complex molecules observed in these environments is still an active area of research, but may be due to higher-density substructures or the passage of shocks through this gas. Diffuse cloud chemistry is most commonly probed through absorption spectroscopy toward background continuum sources.
#
# * **Dense Clouds** ($n=10^2-10^5$ cm$^{-3}$, $T = 10-20$ K): These environments have low temperatures and low ionization fractions but high densities, which increases the collisional rate coefficients, and makes grain-surface reactions productive. As UV light cannot penetrate to the centers of these clouds, the molecules that form here are not subject to photodissociation. The densest substructures in these clouds (for example, cores that are collapsing to form low-mass stars) is also often characterized by a high fraction of deuterated molecules. A classic example of dense cloud chemistry is the Taurus molecular cloud, a quiescent region with no ongoing high-mass star formation. Chemistry in this type of environment (sometimes called dark cloud chemistry) is characterized by the formation of long carbon chains, like HC$_{11}$N, as well as the depletion of some molecules from the gas phase onto the dust grains.
#
# * **Massive Protostellar Envelopes** ($n=10^4-10^{10}$ cm$^{-3}$, $T = 25-2000$ K): These environments have both high densities and high temperatures, which allows formation of some of the most complex molecules observed in the ISM. The high temperatures release molecules formed on grain surfaces into the gas phase, and in the densest of these environments, three-body reactions can become important. Molecules in these environments are often detected through vibrationally-excited transitions as well as rotationally-excited transitions. The classic example of this chemistry (sometimes called hot core chemistry) is the Sgr B2 star forming region in the Galactic center. Of the ~200 molecules detected in space, more than half were discovered here, and nearly all known ISM molecules have ultimately been observed in this source. A more nearby source with slightly less complex chemistry is Orion-KL.
#
# * **Shocks**: These are a common feature of both protostellar envelopes and turbulent gas in the ISM. Recently shocked gas can reach extremely high temperatures and densities that can overcome activation barriers in reactions, and favor neutral-neutral reactions that would otherwise proceed too slowly to be important. Shocks enhance the abundance of Si-bearing species like SiO, and can be observed in vibrationally-excited H$_2$ and masers of CH$_3$OH and H$_2$O.
#
# * **Evolved Star Envelopes** ($n=10^8-10^{11}$ cm$^{-3}$, $T = 600-1000$ K): Not only are these environments important for forming dust grains, they also (perhaps unsurprisingly) can be extremely chemically rich. Here again we have many important ingredients for facilitating chemical reactions: high temperatures, high densities, and an abundance of dust for grain surface reactions. The chemistry in eveolved star envelopes divides into two cases: oxygen-rich (O/C >1, typical of "normal" cosmic abundances) and carbon-rich. In each case, all of the carbon (or oxygen) is locked up in CO, leaving the other species to form the basis of subsequent chemistry. A classic example of carbon-rich envelope chemistry is IRC +10216.
#
# ### Some general classes of molecules
#
# * Molecules that predominately form via grain-surface reactions: H$_2$, NH$_3$, CH$_3$OH
# * Molecules that are typically thermalized: CO, NH3 *Used for temperature measurements*
# * Molecules with large electric dipole moments: HCN, HC$_3$N, HCO$^+$, CS *Used to trace dense (star-forming) gas*
# * Molecules that trace shocks: SiO, CH$_3$OH, masers of OH, H$_2$O, and CH$_3$OH *Used to trace outflows from protostars*
# * Carbon-chain molecules: HC$_n$N, C$_n$S, C$_n$H *Indicative of complex, organic chemistry in relatively quiescent environments*
# * Ions: HCO$^+$, N$_2$H$^+$, H$_3^+$, H$_3$O$^+$ *Abundances measure the degree of ionization in molecular gas and kinematics can give insight into the magnetic structure of the gas*
# * Radicals: OH, CN *Because radicals are highly reactive (due to their unpaired valence electrons), these are most commonly observed in low-density environments*
# * Commonly-substituted isotopes: D/H, $^{12}$C/$^{13}$C, $^{16}$O/$^{18}$O, $^{14}$N/$^{15}$N. *Used for abundance studies and avoiding optical depth issues*
#
# It is useful to mention that not all spectral lines that are observed in space have been identified! A large number of unidentified features (e.g., the diffuse interstellar bands) and lines (as high as 10-15% in millimeter surveys of sources like Sgr B2 and Orion-KL) have been observed, and astronomers have so far been unable to assign them to known molecules. How can this happen? For one, the environment of the ISM is sufficiently different from the terrestrial environment that chemistry (and even just spectra under a wide range of energetic conditions) has not been fully probed in the lab. While some of these lines may be from molecules not yet detected in space, many of the lines may simply originate in the rich vibrational spectra of already-identified complex molecules. There may even be a small number of culprits behind large numbers of unidentified lines: many known ISM molecules already have the reputation of being "weeds" (vinyl cyanide, CH$_2$CHCN, is a notorious example) due to the overwhelming complexity of their spectra!

# %% [markdown]
# # Types of Reactions
#
# We have already seen a large number of examples of chemical reactions throughout this course. To summarize:
#
# * Ionization/Recombination : $\qquad\qquad\qquad\;\;\,$			H + h$\nu 	\rightleftharpoons $    p   +  e$^-$
#
# * Radiative Association/Photodissociation: $\qquad\,$ 		H  + H $\rightleftharpoons$    H$_2$  + h$\nu$
#
# * Collisional Excitation/De-excitation: $\qquad\qquad$		     H + H $\rightleftharpoons$	    H$^*$ + H
#
# * Radiative Excitation/De-excitation:	$\qquad\qquad\;$		     H   + h$\nu \rightleftharpoons$ H$^*$
#
#
# However, some of the most important types of reactions for ISM chemistry are those involving charged species, for which there is a Coulomb attraction that significantly increases the collision/reaction rate. Two important examples of these are:
#
# * Ion-Neutral Reactions: $\qquad\qquad\qquad\qquad\;\;$		H$_2^+$ + H$_2 \rightarrow$	H$_3^+$ + H
#
# * Dissociative Recombination: $\qquad\qquad\qquad\;\;\,$ 	H$_3^+$ + e$^- \rightarrow$ H$_2$  + H
#
# There are also neutral-neutral reactions. In addition to radiative association (which can be either neutral-neutral or ion-neutral) we have:
#
# * Neutral-Neutral Exchange: $\qquad\qquad\qquad\;\;\;$      OH + H $\rightarrow$ O + H$_2$
#
# Already slower than ion-molecule reactions, these reactions generally need to be exothermic in order to proceed at a reasonable rate at the low temperatures that characterize most of the ISM.
#
# ## Reaction Rates
#
# As a reminder: reaction rate coefficients $k_{AB}$ (e.g., for a reaction A+B $\rightarrow$ AB + h$\nu$) have standard units of cm$^3$ s$^{-1}$.
#
# A volumetric reaction rate corresponds to $n_A n_B k_{AB}$ and has units of cm$^{-3}$ s$^{-1}$.
# You will also sometimes encounter a 'per molecule' reaction rate which is equivalent to $n_A k_{AB}$ and has units of just s$^{-1}$.
#
# Whether or not a reaction is likely to be important must be judged against some time scale.
# Ultimately, it had better not be longer than the age of the universe!
# Astrophysically-important time scales include the lifetime of a molecular cloud (max 20- 30 million years), a protostellar disk (max 10 million years), or an asymptotic giant branch star (max 1 million years).
#
# For some common ISM reaction types:
#
# | **Reaction Type** |  | **Typical rate, k**|
# | :- | :- | :- |
# | **Radiative Association**  |   | |
# | [A$^+$ + B $\rightarrow$ AB$^+$ + h$\nu$]  | diatomic  | $10^{-17}$ |
# |  | polyatomic  | $10^{-17}$ to $10^{-9}$ |
# | **Neutral-Neutral** |  |  |
# | [A + B $\rightarrow$ C + D] | neither radical | $10^{-13}$ |
# |  | one or both radical | $10^{-11}$ to $10^{-10}$  |
# | **Ion-Molecule** |  | |
# | [A$^+$ + B $\rightarrow$ C$^+$ + D ] |  | $10^{-9}$ |
# | **Dissociative Recombination** | |  |
# | [A$^+$ +e$^- \rightarrow$ C + B] |  | $10^{-7}$ to $10^{-6}$  |

# %% [markdown]
# # What's what in the ISM?
#
# So how do scientists figure out what molecules they are looking at in the ISM?
#
# Many references compile data taken from theory/computations, laboratory experiments and astronomical observations which include quantum numbers of the transition, the energies of the states involved, and the central line frequency. However, these databases are HUGE, so even searching a frequency range of just 1 GHz (e.g., 100 to 101 GHz) can yield thousands of possible identifications for a line. However, all is not lost.
#
# First, of all, if you know your source velocity to $\pm 10$ km/s, then you should know the frequency to within .003% (so, for a frequency around 100 GHz, this is to within $\pm$ 3 MHz). This helps narrow things down a lot!
#
# Some additional rules of thumb:
# * Making complex molecules is hard enough that simpler species (diatomic/triatomic) are more likely to be abundant and so responsible for strong emission and absorption lines.
# * Similarly, H is at least $1000\times$ more abundant than other (reactive) atoms, so most molecules you see will not contain elements beyond the most common (H,C,N,O,S and Si), and the more non-H atoms in a molecule, the less likely it is to be highly abundant. (Values below from Wilson & Rood 1994)
# ![elemental.png](attachment:elemental.png)
# * Rare isotopes are also, as their name suggests, rare. $^{13}$C is at least 20 times less abundant than $^{12}$C, and rare isotopes of O of N can be several hundred times less abundant. (Values below from Wilson & Rood 1994)
# ![isotopic.png](attachment:isotopic.png)
# * Energy levels are important! In most ISM environments, you are more likely to see transitions with low E$_{up}$ (say, substantially less than a few hundred K). This means that in typical environments, most vibrationally-excited lines will be weak or absent.
#
# These rules apply additively, e.g., if you think you see a vibrationally-excited line of NaH$^{13}$CO$_3$, you should probably question this identification!
#
# Further key considerations:
# * Has anyone ever seen this molecule in space before? (https://en.wikipedia.org/wiki/List_of_interstellar_and_circumstellar_molecules)
# * Can you identify other lines of the same molecule? If not, are there any lines (same molecule, similar level energies) that you *should* be seeing in this frequency range if your identification is correct?
# * How well do you know your source velocity, and are there multiple distinct velocities present in this source?
# * Are the conditions in the source uniform? (for example, do you expect it to contain any shocks or regions where the temperature and density are extremely different than the average values)

# %% [markdown]
# # Group/Individual Challenge!
#
# It's time to test our line identification skills using an online molecular database!
# We will use Splatalogue, a database optimized for submillimeter, millimeter, and radio line identification: https://splatalogue.online//advanced.php
#
# This image is a "mystery" spectrum taken with the ALMA observatory toward the center of a nearby starburst galaxy (NGC 253). You can assume that the gas in this environment is dense and warm ($\sim300$ K).
#
# ![mystery_spectrum.png](attachment:mystery_spectrum.png)
#
# A table of measured line frequencies is below. The rest velocity of the gas in this part of the galaxy is $\sim200\pm10$ km/s.
#
# ![meas_freqs.png](attachment:meas_freqs.png)
#
#
# Using this information, identify as many of these lines as you can!

# %%
import numpy as np                          # I use this for maths and sometimes arrays.
                                            # "np" is just an abbreviation since we call this package so often!
import pylab                                # I use this for arrays and plotting sometimes
import matplotlib
import matplotlib.pyplot as plt                    # Standard plotting package
import scipy

from astropy import units as u              # This one helps with unit conversion
from astropy import constants as const
from astropy.io import fits


                                            # Super important!! 
                                            # This embeds plots in the Jupyter window 
                                            # (instead of showing them as pop-ups)
# %matplotlib inline                             

plt.rc('font', family='sans-serif')  # Set plot fonts
plt.rc('text', usetex=True)      
#plt.rc('text', usetex=False)        # This is a quick fix if you don't have latex on your computer


meas_nu = np.array([354.2535,  354.4666, 354.8141,355.0589,355.2058,355.3361,355.8505,356.0264,356.4877,356.9317,357.0044,357.1530,357.3462,357.4391])

# %%
#1st Entry: Hydrogen Cyanide (HCN) v=0, E_upper = 42.53465 K 
#2nd Entry: HC3N Cyanoacetylene, E_upper = 340.51429 K
#3rd Entry: SO2 , E_upper = 110.99905 K 



v = 200 * 1000
rest_nu = [freq_val/(1- v/(2.99e8)) for freq_val in meas_nu]
rest_upper = [freq_val/(1- (v+ 10*1000)/(2.99e8)) for freq_val in meas_nu]
rest_lower = [freq_val/(1- (v- 10*1000)/(2.99e8)) for freq_val in meas_nu]
print('Rest frequencies: ')
for freq in rest_nu:\
    print(freq)
# Out:
# Rest frequencies:
# 354.4906174698795
# 354.70386010709507
# 355.0515927041499
# 355.2965565595716
# 355.44355488621153
# 355.5739421017403
# 356.08868641231595
# 356.2647041499331
# 356.72631291834006
# 357.17061010709506
# 357.24335876840695
# 357.39205823293173
# 357.58538755020083
# 357.6783497322624
